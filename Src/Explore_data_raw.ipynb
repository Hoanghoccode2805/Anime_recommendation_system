# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler,LabelEncoder
from surprise import Dataset, Reader
from surprise.model_selection import train_test_split
from surprise import SVD
from surprise import accuracy
from tqdm import tqdm

# A. Load and Prepare the Data
# Load the dataset
address = r"D:\Full projet\Anime_recommendation_system\Data\full_raw_data.csv"
df_raw = pd.read_csv(address)

# Define the reader
reader = Reader(rating_scale=(1,10))

# Load the data into Surprise
data = Dataset.load_from_df(df_raw[['user_id', 'anime_id', 'rating']], reader)

# %%
print(df_raw['rating'].describe())
print(df_raw['rating'].value_counts(normalize=True).sort_index())
# Out:
# count    1.672284e+07
# mean     7.353800e+00
# std      1.603874e+00
# min      1.000000e+00
# 25%      7.000000e+00
# 50%      7.000000e+00
# 75%      8.000000e+00
# max      1.000000e+01
# Name: rating, dtype: float64
# rating
# 1     0.003885
# 2     0.005882
# 3     0.011847
# 4     0.026016
# 5     0.065816
# 6     0.136011
# 7     0.261766
# 8     0.261196
# 9     0.144340
# 10    0.083240
# Name: proportion, dtype: float64

# %%
# Kiểm tra: trung bình mỗi user có bao nhiêu anime rating >= 9 trong TOÀN BỘ data
print(df_raw[df_raw['rating']>=9].groupby('user_id').size().describe())
# Out:
# count    22982.000000
# mean       165.598599
# std        151.781459
# min          1.000000
# 25%         70.000000
# 50%        127.000000
# 75%        214.000000
# max       6405.000000
# dtype: float64

# %%
top_user = df_raw[df_raw['rating']>=7].groupby('user_id').size().idxmax()
print(df_raw[df_raw['user_id']==top_user]['rating'].describe())
# Out:
# count    6773.000000
# mean        7.001772
# std         0.333230
# min         6.000000
# 25%         7.000000
# 50%         7.000000
# 75%         7.000000
# max        10.000000
# Name: rating, dtype: float64
