# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
address = r"D:\Full projet\Anime_recommendation_system\Data\my_anime_raw_dataset.csv"
df = pd.read_csv(address)

# %%
df.head()
# Out:
#    anime_id                                             title  score  rank  \
# 0     52991                                 Sousou no Frieren   9.26   1.0
# 1     61316  Re:Zero kara Hajimeru Isekai Seikatsu 4th Season   9.20   2.0
# 2     61469          Steel Ball Run: JoJo no Kimyou na Bouken   9.11   4.0
# 3      5114                  Fullmetal Alchemist: Brotherhood   9.11   3.0
# 4      9253                                       Steins;Gate   9.07   5.0
#
#    popularity  members  favorites  episodes type  \
# 0         103  1470294      91117      28.0   TV
# 1        1021   277729       6059      19.0   TV
# 2        1300   217763       7474       NaN  ONA
# 3           3  3704780     243851      64.0   TV
# 4          14  2828935     203495      24.0   TV
#
#                            rating       duration            status  \
# 0       PG-13 - Teens 13 or older  24 min per ep   Finished Airing
# 1  R - 17+ (violence & profanity)  23 min per ep  Currently Airing
# 2  R - 17+ (violence & profanity)         47 min  Currently Airing
# 3  R - 17+ (violence & profanity)  24 min per ep   Finished Airing
# 4       PG-13 - Teens 13 or older  24 min per ep   Finished Airing
#
#                                   genres           studios
# 0  Adventure,Award Winning,Drama,Fantasy          Madhouse
# 1                 Drama,Fantasy,Suspense         White Fox
# 2  Action,Adventure,Mystery,Supernatural  David Production
# 3         Action,Adventure,Drama,Fantasy             Bones
# 4                  Drama,Sci-Fi,Suspense         White Fox

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9975 entries, 0 to 9974
# Data columns (total 14 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   anime_id    9975 non-null   int64
#  1   title       9975 non-null   object
#  2   score       9975 non-null   float64
#  3   rank        8563 non-null   float64
#  4   popularity  9975 non-null   int64
#  5   members     9975 non-null   int64
#  6   favorites   9975 non-null   int64
#  7   episodes    9874 non-null   float64
#  8   type        9975 non-null   object
#  9   rating      9957 non-null   object
#  10  duration    9975 non-null   object
#  11  status      9975 non-null   object
#  12  genres      9303 non-null   object
#  13  studios     9366 non-null   object
# dtypes: float64(3), int64(4), object(7)
# memory usage: 1.1+ MB

# %%
df.describe()
# Out:
#            anime_id        score         rank    popularity       members  \
# count   9975.000000  9975.000000  8563.000000   9975.000000  9.975000e+03
# mean   26820.813033     7.119184  4281.902254   6635.439599  1.099250e+05
# std    21195.305320     0.536189  2475.225934   4832.933228  2.813096e+05
# min        1.000000     6.390000     1.000000      1.000000  1.830000e+02
# 25%     4791.000000     6.680000  2132.000000   2697.500000  4.914500e+03
# 50%    28405.000000     7.040000  4292.000000   5754.000000  1.819300e+04
# 75%    44844.000000     7.450000  6424.500000   9659.500000  8.419350e+04
# max    64483.000000     9.260000  8586.000000  24154.000000  4.388048e+06
#
#            favorites     episodes
# count    9975.000000  9874.000000
# mean     1282.971429    14.490075
# std      7895.169377    41.453977
# min         0.000000     1.000000
# 25%         8.000000     1.000000
# 50%        41.000000     6.000000
# 75%       275.000000    13.000000
# max    253774.000000  1787.000000

# %%
df.hist()
plt.plot()
# Out:
# []

# %%
non_null_percentage = df.notna().mean() * 100
print(non_null_percentage)
# Out:
# anime_id      100.000000
# title         100.000000
# score         100.000000
# rank           85.844612
# popularity    100.000000
# members       100.000000
# favorites     100.000000
# episodes       98.987469
# type          100.000000
# rating         99.819549
# duration      100.000000
# status        100.000000
# genres         93.263158
# studios        93.894737
# dtype: float64

# %%
plt.scatter(df['favorites'],df['score'], color = 'blue')
plt.xlabel("Favorites")
plt.ylabel("Scores")
plt.show()
