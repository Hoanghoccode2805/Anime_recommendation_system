# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
address = r"D:\Full projet\Anime_recommendation_system\Data\user_rating_small.csv"
df = pd.read_csv(address)
# Out:
# C:\Users\Hoang\AppData\Local\Temp\ipykernel_13964\1950634066.py:2: DtypeWarning: Columns (0,1,2) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(address)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43388185 entries, 0 to 43388184
# Data columns (total 3 columns):
#  #   Column    Dtype
# ---  ------    -----
#  0   user_id   object
#  1   anime_id  object
#  2   rating    object
# dtypes: object(3)
# memory usage: 993.1+ MB

# %%
(df['user_id'].dtypes)
# Out:
# dtype('O')

# %%
df = df[df['user_id'] != 'user_id']
df = df[df['rating'] != 'rating']

# %%
df['user_id'] = df['user_id'].astype(int)
df['rating'] = df['rating'].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 43388174 entries, 0 to 43388184
# Data columns (total 3 columns):
#  #   Column    Dtype
# ---  ------    -----
#  0   user_id   int64
#  1   anime_id  object
#  2   rating    int64
# dtypes: int64(2), object(1)
# memory usage: 1.3+ GB

# %%
df.to_csv(r"D:\Full projet\Anime_recommendation_system\Data\user_rating_small.csv", index=False)
