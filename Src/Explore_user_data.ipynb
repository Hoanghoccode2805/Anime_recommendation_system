# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
address = r"D:\Full projet\Anime_recommendation_system\Data\user_rating_small.csv"
df = pd.read_csv(address)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43388174 entries, 0 to 43388173
# Data columns (total 3 columns):
#  #   Column    Dtype
# ---  ------    -----
#  0   user_id   int64
#  1   anime_id  int64
#  2   rating    int64
# dtypes: int64(3)
# memory usage: 993.1 MB

# %%
(df['user_id'].dtypes)
# Out:
# dtype('O')

# %%
df = df[df['user_id'] != 'user_id']
df = df[df['rating'] != 'rating']
df = df[df['anime_id'] != 'anime_id']

# %%
df['user_id'] = df['user_id'].astype(int)
df['rating'] = df['rating'].astype(int)
df['anime_id'] = df['anime_id'].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43388174 entries, 0 to 43388173
# Data columns (total 3 columns):
#  #   Column    Dtype
# ---  ------    -----
#  0   user_id   int64
#  1   anime_id  int64
#  2   rating    int64
# dtypes: int64(3)
# memory usage: 993.1 MB

# %%
df.to_csv(r"D:\Full projet\Anime_recommendation_system\Data\user_rating_small.csv", index=False)

# %%
print(df['rating'].min())
# Out:
# 1

# %%
print(df['rating'].max())
# Out:
# 10

# %%
df1 = df.query("rating > 8.5")
df1
# Out:
#           user_id  anime_id  rating
# 1              17      6682      10
# 9              17     19221      10
# 11             17     20939      10
# 15             17     29803       9
# 17             17     28927       9
# ...           ...       ...     ...
# 43388163   353325        52       9
# 43388165   353325      4672      10
# 43388166   353325      5079       9
# 43388172   353325      2162       9
# 43388173   353325       467       9
#
# [7799233 rows x 3 columns]

# %%
print(df['rating'].describe())
print(df['rating'].value_counts(normalize=True).sort_index())
# Out:
# count    4.338817e+07
# mean     6.912236e+00
# std      1.859730e+00
# min      1.000000e+00
# 25%      6.000000e+00
# 50%      7.000000e+00
# 75%      8.000000e+00
# max      1.000000e+01
# Name: rating, dtype: float64
# rating
# 1     0.013613
# 2     0.015019
# 3     0.024059
# 4     0.043803
# 5     0.094930
# 6     0.159165
# 7     0.252862
# 8     0.216794
# 9     0.110379
# 10    0.069376
# Name: proportion, dtype: float64

# %%
print(df[df['rating']>=7].groupby('user_id').size().describe())
# Out:
# count     23003.000000
# mean       1224.916576
# std        2798.500850
# min           9.000000
# 25%         419.000000
# 50%         528.000000
# 75%         731.000000
# max      178368.000000
# dtype: float64
